# %% [markdown]
# # 0. Постановка задачи
# Предсказываем банкротство польских компаний по 64 финансовым коэффициентам из набора данных Kaggle "Predict Bankruptcy in Poland". Целевая переменная class:
#
# - 0 — компания продолжает работу;
# - 1 — компания обанкротилась.
# - Это задача бинарной классификации с сильным дисбалансом классов.

# %% [markdown]
# # 1. Загрузка данных
#
# Используем файл archive/data.csv, где каждая строка — компания в конкретный год до возможного банкротства. Считаем таблицу, посмотрим на размерность и первые строки.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %matplotlib inline

DATA_PATH = Path('archive/data.csv')
data_raw = pd.read_csv(DATA_PATH)

print('Размеры набора данных:', data_raw.shape)
display(data_raw.head())
data_raw.info()

# Создаем data_model, удаляя колонку A37 с большим количеством пропусков
print("\nУдаляем признак A37 (43.74% пропусков)")
data_model = data_raw.drop(columns=['A37'])
print(f'Размерность data_model: {data_model.shape}')
# Out:
# Размеры набора данных: (43405, 66)
#          A1       A2       A3      A4       A5       A6        A7       A8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#        A9      A10  ...      A57      A58       A59     A60     A61      A62  \
# 0  1.1389  0.50494  ...  0.39718  0.87804  0.001924  8.4160  5.1372   82.658
# 1  1.6996  0.49788  ...  0.42002  0.85300  0.000000  4.1486  3.2732  107.350
# 2  1.3090  0.30408  ...  0.81774  0.76599  0.694840  4.9909  3.9510  134.270
# 3  1.0571  0.57353  ...  0.14207  0.94598  0.000000  4.5746  3.6147   86.435
# 4  1.1559  0.38677  ...  0.48431  0.86515  0.124440  6.3985  4.3158  127.210
#
# ...

# %% [markdown]
# # 2. Разведочный анализ (EDA)
#
# Смотрим распределения числовых признаков, доли классов, пропуски и корреляции, чтобы понимать структуру данных перед моделированием.

# %%
# Числовые признаки (на очищенных данных):
num_summary = data_model.describe().T
num_summary.head()
# Out:
#       count        mean           std           min        25%      50%  \
# A1  43397.0    0.035160      2.994109 -4.638900e+02   0.003429  0.04966
# A2  43397.0    0.590212      5.842748 -4.308700e+02   0.268980  0.47190
# A3  43397.0    0.114431      5.439429 -4.799600e+02   0.021521  0.19661
# A4  43271.0    6.314702    295.434425 -4.031100e-01   1.049500  1.56980
# A5  43316.0 -385.346602  61243.025874 -1.190300e+07 -49.080000 -1.03450
#
#          75%          max
# A1   0.12958       94.280
# A2   0.68832      480.960
# A3   0.40339       28.336
# A4   2.78745    53433.000
# A5  50.63425  1250100.000

# %%
# Баланс классов 
class_counts = data_model['class'].value_counts()
class_share = data_model['class'].value_counts(normalize=True)
print('Абсолютные значения:\n', class_counts)
print('\nДоли классов:\n', class_share)

sns.barplot(x=class_counts.index.astype(str), y=class_counts.values)
plt.title('Распределение класса (0=действующая, 1=банкрот)')
plt.ylabel('Количество компаний')
plt.show()
# Out:
# Абсолютные значения:
#  class
# 0    41314
# 1     2091
# Name: count, dtype: int64
#
# Доли классов:
#  class
# 0    0.951826
# 1    0.048174
# Name: proportion, dtype: float64

# %%
# Пропущенные значения: считаем абсолютные и относительные
missing = data_raw.isna().sum().sort_values(ascending=False)
missing_pct = (missing / len(data_raw) * 100).round(2)
missing_summary = pd.DataFrame({'missing': missing, 'missing_%': missing_pct})
print("Топ-10 признаков с пропусками:")
display(missing_summary.head(10))
# Out:
# Топ-10 признаков с пропусками:
#      missing  missing_%
# A37    18984      43.74
# A21     5854      13.49
# A27     2764       6.37
# A60     2152       4.96
# A45     2147       4.95
# A24      922       2.12
# A64      812       1.87
# A53      812       1.87
# A54      812       1.87
# A28      812       1.87

# %%
# Матрица корреляций (на очищенных данных)
corr_with_class = data_model.corr()['class'].abs().sort_values(ascending=False)

plt.figure(figsize=(14, 8))
top_features = corr_with_class.index[1:16]
bars = plt.bar(top_features, corr_with_class[top_features])

plt.title('Корреляция признаков с банкротством', fontsize=14, pad=20)
plt.xlabel('Признаки', fontsize=12)
plt.ylabel('|ρ|', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 0.1)

for bar, value in zip(bars, corr_with_class[top_features]):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.002, 
             f'{value:.4f}', ha='center', fontsize=9)

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

top_15_with_class = list(corr_with_class.index[:16])

plt.figure(figsize=(16, 12))
corr_matrix = data_model[top_15_with_class].corr()

sns.heatmap(corr_matrix, 
            annot=True,
            fmt='.3f',
            cmap='coolwarm',
            center=0,
            square=True,
            cbar_kws={'shrink': 0.8},
            linewidths=0.5,
            linecolor='gray')

plt.title('Матрица корреляций: 15 лучших признаков + class', fontsize=14, pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

print("Топ-16 признаков по корреляции с банкротством:")
print(corr_with_class.head(16))
# Out:
# Топ-16 признаков по корреляции с банкротством:
# class    1.000000
# A29      0.055717
# year     0.043488
# A2       0.035236
# A3       0.035128
# A51      0.034753
# A6       0.034662
# A1       0.026649
# A55      0.022101
# A39      0.019850
# A57      0.019204
# A25      0.018415
# A35      0.018003
# A11      0.016147
# A12      0.016108
# A18      0.016053
# Name: class, dtype: float64

# %% [markdown]
#  Наблюдения по EDA:
# - Все 66 столбцов числовые; большинство имеют пропуски <5%, но есть признаки с существенными пропусками (например, `A37`).
# - Дисбаланс классов выраженный: банкроты составляют ~5% выборки — позже применим балансировку.
# - Корреляции показывают, что признаки из группы `A29`, `year`, `A2`, `A3`, `A51` сильнее всего связаны с целевой переменной; часть коэффициентов сильно коррелирует друг с другом, поэтому позже удалим дубли.

# %% [markdown]
# # 3. Обработка пропусков
#
# Все признаки числовые, поэтому заполним пропуски медианами — это нужно, чтобы kNN и другие модели корректно обучались.

# %%
from sklearn.impute import SimpleImputer

# Обработка пропусков медианой
feature_cols = [col for col in data_model.columns if col != 'class']
X = data_model[feature_cols].copy()
y = data_model['class'].copy()

num_imputer = SimpleImputer(strategy='median')
X_imputed = pd.DataFrame(num_imputer.fit_transform(X), columns=feature_cols)

print('Количество пропусков после заполнения:', X_imputed.isna().sum().sum())
print(f'Размерность X_imputed: {X_imputed.shape}')
print(f'Размерность y: {y.shape}')
# Out:
# Количество пропусков после заполнения: 0
# Размерность X_imputed: (43405, 64)
# Размерность y: (43405,)

# %% [markdown]
# # 4. Обработка категориальных признаков
#
# В отличие от примера `12-6` с квартирами, где были признаки `Type` и `Building`, этот набор содержит только числовые коэффициенты `A1`-`A64` и признак `year`. Поэтому дополнительных преобразований не требуется просто фиксируем это явно.

# %% [markdown]
# # 5. Нормализация признаков

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X_imputed), columns=feature_cols)
X_scaled.head()
# Out:
#          A1        A2        A3        A4        A5        A6        A7  \
# 0  0.055243 -0.036062  0.051842 -0.014418  0.006815  0.061710  0.027359
# 1  0.058106 -0.015458  0.065787 -0.014765  0.006527  0.007791  0.028861
# 2  0.071313  0.018098  0.028073 -0.016087  0.006267  0.007791  0.037740
# 3  0.015472 -0.048415  0.063312 -0.012907  0.007135  0.028606 -0.000134
# 4  0.050824  0.003944  0.021172 -0.016590  0.006166  0.033805  0.016429
#
#          A8        A9       A10  ...       A56       A57       A58       A59  \
# 0 -0.022332 -0.024044 -0.008310  ...  0.004937  0.029816 -0.005459 -0.010903
# 1 -0.022994 -0.015133 -0.008792  ...  0.004937  0.031487 -0.005464 -0.010918
# 2 -0.024100 -0.021341 -0.022003  ...  0.004959  0.060575 -0.005480 -0.005227
# 3 -0.021272 -0.025344 -0.003635  ...  0.004924  0.011158 -0.005446 -0.010918
# 4 -0.023717 -0.023774 -0.016366  ...  0.004939  0.036189 -0.005461 -0.009899
#
#         A60       A61       A62       A63       A64      year
# ...

# %% [markdown]
# Теперь все признаки с нулевым средним и единичным стандартным отклонением — можно переходить к разбиению на train/test и настройке моделей.

# %% [markdown]
# Категориальных признаков нет (все столбцы числовые коэффициенты), поэтому one-hot кодирование не требуется.

# %% [markdown]
# # 6. Разбиение на обучающую и тестовую выборки
#
# Разделяем данные на train/test (80/20) с сохранением долей классов (`stratify=y`).

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_imputed, y, test_size=0.2, random_state=42, stratify=y
)

print('Train shape:', X_train.shape)
print('Test shape:', X_test.shape)
print('Доля класса 1 в train:', y_train.mean().round(4))
print('Доля класса 1 в test:', y_test.mean().round(4))
# Out:
# Train shape: (34724, 64)
# Test shape: (8681, 64)
# Доля класса 1 в train: 0.0482
# Доля класса 1 в test: 0.0482

# %% [markdown]
# # 7. Базовый классификатор k ближайших соседей(kNN)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_auc_score

knn_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=5))
])

knn_pipeline.fit(X_train, y_train)
y_pred_knn = knn_pipeline.predict(X_test)
y_proba_knn = knn_pipeline.predict_proba(X_test)[:, 1]

acc = accuracy_score(y_test, y_pred_knn)
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_knn, average='binary')
roc_auc = roc_auc_score(y_test, y_proba_knn)

print(f"Базовый kNN (k=5): accuracy={acc:.3f}, precision={precision:.3f}, recall={recall:.3f}, F1={f1:.3f}, ROC-AUC={roc_auc:.3f}")
# Out:
# Базовый kNN (k=5): accuracy=0.949, precision=0.245, recall=0.031, F1=0.055, ROC-AUC=0.597

# %% [markdown]
# ## 8. Подбор оптимального числа соседей
#
# Используем `GridSearchCV` по нечётным значениям `k` (3–31) и максимальным соседям, оптимизируем `f1`.

# %%
from sklearn.model_selection import GridSearchCV

# Оптимизированная сетка для ускорения
param_grid = {'knn__n_neighbors': [3, 5, 7, 9, 11, 15, 19]}
grid_search = GridSearchCV(
    knn_pipeline,
    param_grid,
    scoring='f1',
    cv=3,  # Уменьшено с 5 до 3 для ускорения
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)
print('Лучший k:', grid_search.best_params_)
print('Лучший F1 (CV):', grid_search.best_score_.round(3))
# Out:
# Fitting 3 folds for each of 7 candidates, totalling 21 fits
# Лучший k: {'knn__n_neighbors': 3}
# Лучший F1 (CV): 0.084

# %% [markdown]
# # 9. Оценка качества на обучении и тесте
#
# Берём лучший kNN из поиска и сравниваем ошибки/метрики на train и test. Используем accuracy, precision, recall, F1 и ROC-AUC.

# %%
best_knn = grid_search.best_estimator_
y_pred_train = best_knn.predict(X_train)
y_pred_test = best_knn.predict(X_test)
y_proba_train = best_knn.predict_proba(X_train)[:, 1]
y_proba_test = best_knn.predict_proba(X_test)[:, 1]

def print_metrics(y_true, y_pred, y_proba, label):
    acc = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='binary')
    roc_auc = roc_auc_score(y_true, y_proba)
    print(f"{label}: accuracy={acc:.3f}, precision={precision:.3f}, recall={recall:.3f}, F1={f1:.3f}, ROC-AUC={roc_auc:.3f}")

print_metrics(y_train, y_pred_train, y_proba_train, 'Train')
print_metrics(y_test, y_pred_test, y_proba_test, 'Test')
# Out:
# Train: accuracy=0.959, precision=0.751, recall=0.213, F1=0.332, ROC-AUC=0.967
# Test: accuracy=0.945, precision=0.223, recall=0.060, F1=0.094, ROC-AUC=0.571

# %% [markdown]
# # 10. Другие классификаторы и подбор параметров
#
# Для сравнения пробуем логистическую регрессию (с регуляризацией `C`) и случайный лес (параметры `n_estimators`, `max_depth`).

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

logreg_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(max_iter=1000, random_state=42))
])

rf_pipeline = Pipeline([
    ('clf', RandomForestClassifier(random_state=42))
])

# Упрощенная сетка для ускорения
logreg_grid = {'clf__C': [0.1, 1, 10], 'clf__class_weight': [None]}
rf_grid = {'clf__n_estimators': [100, 200], 'clf__max_depth': [10, 20]}

logreg_search = GridSearchCV(logreg_pipeline, logreg_grid, scoring='f1', cv=3, n_jobs=-1)  # cv=3
rf_search = GridSearchCV(rf_pipeline, rf_grid, scoring='f1', cv=3, n_jobs=-1)  # cv=3

logreg_search.fit(X_train, y_train)
rf_search.fit(X_train, y_train)

print('Best LogisticRegression params:', logreg_search.best_params_, 'F1:', round(logreg_search.best_score_, 3))
print('Best RandomForest params:', rf_search.best_params_, 'F1:', round(rf_search.best_score_, 3))
# Out:
# Best LogisticRegression params: {'clf__C': 10, 'clf__class_weight': None} F1: 0.024
# Best RandomForest params: {'clf__max_depth': 20, 'clf__n_estimators': 200} F1: 0.357

# %%
models = {
    'kNN_best': best_knn,
    'LogReg': logreg_search.best_estimator_,
    'RandomForest': rf_search.best_estimator_
}

results = []
for name, model in models.items():
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    acc = accuracy_score(y_test, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
    roc_auc = roc_auc_score(y_test, y_proba)
    results.append({'model': name, 'accuracy': acc, 'precision': precision, 'recall': recall, 'f1': f1, 'roc_auc': roc_auc})

pd.DataFrame(results).round(3)
# Out:
#           model  accuracy  precision  recall     f1  roc_auc
# 0      kNN_best     0.945      0.223   0.060  0.094    0.571
# 1        LogReg     0.951      0.300   0.007  0.014    0.675
# 2  RandomForest     0.963      0.888   0.266  0.409    0.925

# %% [markdown]
# # 11. Борьба с дисбалансом классов
#
# Класс 1 составляет ~5% данных, поэтому precision/recall падают. Как минимум два подхода: (1) использовать веса классов, (2) увеличить число объектов редкого класса (oversampling). Покажем, как простое oversampling улучшает полноту.

# %%
from sklearn.utils import resample
from sklearn.base import clone

train_df = X_train.copy()
train_df['class'] = y_train.values
majority = train_df[train_df['class'] == 0]
minority = train_df[train_df['class'] == 1]

minority_up = resample(minority, replace=True, n_samples=len(majority), random_state=42)
train_balanced = pd.concat([majority, minority_up]).sample(frac=1, random_state=42)

X_train_bal = train_balanced.drop(columns='class')
y_train_bal = train_balanced['class']

balanced_logreg = clone(logreg_search.best_estimator_)
balanced_logreg.fit(X_train_bal, y_train_bal)

y_pred_bal = balanced_logreg.predict(X_test)
y_proba_bal = balanced_logreg.predict_proba(X_test)[:, 1]
print_metrics(y_test, y_pred_bal, y_proba_bal, 'Test (LogReg + oversampling)')
# Out:
# Test (LogReg + oversampling): accuracy=0.731, precision=0.106, recall=0.617, F1=0.181, ROC-AUC=0.741

# %% [markdown]
# # 12. Исключение сильно коррелированных признаков
#
# Как отмечалось в EDA, многие коэффициенты линейно связаны. Высокая корреляция ухудшает интерпретацию и может мешать линейным моделям. Удаляем признаки с |corr| > 0.95 (по верхнему треугольнику корреляционной матрицы).

# %%
corr_matrix = X_imputed.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
features_to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

print('Сильно коррелирующих признаков:', len(features_to_drop))
X_reduced = X_imputed.drop(columns=features_to_drop)

X_train_red, X_test_red, y_train_red, y_test_red = train_test_split(
    X_reduced, y, test_size=0.2, random_state=42, stratify=y
)

logreg_reduced = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(max_iter=1000, random_state=42))
])

logreg_reduced.fit(X_train_red, y_train_red)
y_pred_red = logreg_reduced.predict(X_test_red)
y_proba_red = logreg_reduced.predict_proba(X_test_red)[:, 1]
print_metrics(y_test_red, y_pred_red, y_proba_red, 'LogReg на урезанном наборе')
# Out:
# Сильно коррелирующих признаков: 21
# LogReg на урезанном наборе: accuracy=0.952, precision=0.400, recall=0.005, F1=0.009, ROC-AUC=0.620

# %%
logreg_reduced = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(max_iter=1000, random_state=42, class_weight='balanced'))  
])

logreg_reduced.fit(X_train_red, y_train_red)
y_pred_red = logreg_reduced.predict(X_test_red)
y_proba_red = logreg_reduced.predict_proba(X_test_red)[:, 1]
print_metrics(y_test_red, y_pred_red, y_proba_red, 'LogReg на урезанном наборе')
# Out:
# LogReg на урезанном наборе: accuracy=0.722, precision=0.098, recall=0.584, F1=0.168, ROC-AUC=0.701

# %% [markdown]
# # 13. Общие выводы
#
# В этой работе я решал задачу предсказания банкротства польских компаний на основе 64 финансовых коэффициентов. Данные оказались довольно сложными из-за сильного дисбаланса классов — банкротов всего около 5% от всей выборки.
#
# Начал с базового метода k ближайших соседей. Без настройки параметров результаты были посредственными, а после подбора оптимального значения k получилось немного лучше, но всё равно модель плохо находила банкротов. Это ожидаемо, потому что kNN чувствителен к дисбалансу — он склонен относить большинство компаний к доминирующему классу.
#
# Потом попробовал логистическую регрессию и случайный лес. Случайный лес оказался значительно лучше всех остальных методов. Он показал ROC-AUC = 0.925 и F1 = 0.409, что намного превосходит другие подходы. При этом у него очень высокая точность (precision = 0.888), хотя полнота немного ниже (recall = 0.266). Это значит, что когда случайный лес предсказывает банкротство, он почти всегда прав, но находит только около четверти реальных банкротов.
#
# Интересно получилось с применением oversampling к логистической регрессии. После искусственного увеличения числа примеров редкого класса recall подскочил до 0.617 — модель стала находить больше половины банкротов. Но при этом сильно упала точность (precision = 0.106), то есть появилось много ложных тревог. Для практического применения выбор между этими двумя подходами зависит от того, что важнее — не пропустить банкротов (тогда LogReg + oversampling) или избежать ложных срабатываний (тогда RandomForest).
#
# На этапе удаления сильно коррелированных признаков я убрал 21 признак из 64. Это упростило модель, но результаты даже немного ухудшились, что показывает важность этих признаков несмотря на корреляцию. Наверное, для линейных моделей такое удаление полезнее, а для деревьев можно было оставить все признаки.
#
# Если бы нужно было выбирать одну модель для реального использования, я бы остановился на случайном лесе — он показал лучшее общее качество и не требует дополнительных манипуляций с балансировкой данных.

# %% [markdown]
# # Лабораторная №2: Кластеризация
#
# Задача: применить методы обучения без учителя для кластеризации компаний на основе финансовых коэффициентов.
#
# Важно: целевая метка class не используется при обучении кластеризации. Она используется только для оценки результатов.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, adjusted_rand_score

# Подготовка данных для кластеризации
df_cluster = pd.read_csv('archive/data.csv')
df_cluster = df_cluster.dropna()

# Сохраняем истинные метки для сравнения (не для обучения)
y_true = df_cluster['class'].values

# Подготовка признаков без целевой метки
X_clustering = df_cluster.drop(['class', 'year'], axis=1)

# Стандартизация
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_clustering)

print(f"Размер данных: {X_scaled.shape}")
print(f"Количество объектов: {X_scaled.shape[0]}")
print(f"Количество признаков: {X_scaled.shape[1]}")
# Out:
# Размер данных: (19967, 64)
# Количество объектов: 19967
# Количество признаков: 64

# %%
# PCA для визуализации
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

print(f"Объясненная дисперсия:")
print(f"  Компонента 1: {pca.explained_variance_ratio_[0]:.3f}")
print(f"  Компонента 2: {pca.explained_variance_ratio_[1]:.3f}")
print(f"  Всего: {pca.explained_variance_ratio_.sum():.3f}")

plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_true, cmap='RdYlGn_r', alpha=0.6, edgecolors='black', linewidths=0.5)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA: истинные метки')
plt.colorbar(label='Class')
plt.show()
# Out:
# Объясненная дисперсия:
#   Компонента 1: 0.174
#   Компонента 2: 0.109
#   Всего: 0.283

# %%
# PCA визуализация - два графика: полный и увеличенный
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# График 1: Полные данные
scatter1 = axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=y_true, 
                          cmap='RdYlGn_r', alpha=0.6, 
                          edgecolors='black', linewidths=0.5, s=10)
axes[0].set_xlabel('PC1')
axes[0].set_ylabel('PC2')
axes[0].set_title('PCA: все данные с истинными метками')
axes[0].grid(True, alpha=0.3)

# График 2: Увеличенная область основного облака
# Определяем границы основного облака (где ~95% данных)
main_area_mask = (X_pca[:, 0] > -10) & (X_pca[:, 0] < 10) & \
                 (X_pca[:, 1] > -10) & (X_pca[:, 1] < 10)

scatter2 = axes[1].scatter(X_pca[main_area_mask, 0], X_pca[main_area_mask, 1], 
                          c=y_true[main_area_mask], cmap='RdYlGn_r', 
                          alpha=0.7, edgecolors='black', linewidths=0.5, s=20)
axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title('PCA: увеличенная область основного облака (-10, 10)')
axes[1].grid(True, alpha=0.3)

# Добавляем общую легенду для цветов
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', 
                          markerfacecolor='green', markersize=10, label='Не банкроты'),
                   Line2D([0], [0], marker='o', color='w', 
                          markerfacecolor='red', markersize=10, label='Банкроты')]

axes[0].legend(handles=legend_elements)
axes[1].legend(handles=legend_elements)

plt.tight_layout()
plt.show()

# Дополнительная информация о количестве точек в увеличенной области
print(f"Всего точек: {len(X_pca)}")
print(f"Точек в увеличенной области (-10, 10): {main_area_mask.sum()} ({main_area_mask.sum()/len(X_pca):.1%})")
print(f"Банкротов в увеличенной области: {y_true[main_area_mask].sum()} ({y_true[main_area_mask].sum()/y_true.sum():.1%} от всех банкротов)")
# Out:
# Всего точек: 19967
# Точек в увеличенной области (-10, 10): 19927 (99.8%)
# Банкротов в увеличенной области: 432 (100.0% от всех банкротов)

# %% [markdown]
# KMeans

# %%
# Подбор оптимального количества кластеров
range_k = range(2, 11)
silhouette_scores = []

for k in range_k:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    cluster_labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(X_scaled, cluster_labels))

plt.figure(figsize=(10, 6))
plt.plot(range_k, silhouette_scores, marker='o', color='blue')
plt.xlabel('Количество кластеров (k)')
plt.ylabel('Silhouette Score')
plt.title('Подбор оптимального k для KMeans')
plt.grid(True, alpha=0.3)
plt.show()

optimal_k = range_k[np.argmax(silhouette_scores)]
print(f"Оптимальное k: {optimal_k}")
print(f"Максимальный Silhouette Score: {max(silhouette_scores):.4f}")
# Out:
# Оптимальное k: 2
# Максимальный Silhouette Score: 0.9887

# %%
# Обучение KMeans с оптимальным k
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
kmeans.fit(X_scaled)
kmeans_labels = kmeans.labels_

# Метрики
silhouette_kmeans = silhouette_score(X_scaled, kmeans_labels)
ari_kmeans = adjusted_rand_score(y_true, kmeans_labels)

print(f"KMeans (k={optimal_k}):")
print(f"  Silhouette Score: {silhouette_kmeans:.4f}")
print(f"  ARI: {ari_kmeans:.4f}")

# Визуализация
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis', alpha=0.6, edgecolors='black', linewidths=0.5)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('KMeans')
plt.colorbar(label='Кластер')
plt.show()
# Out:
# KMeans (k=2):
#   Silhouette Score: 0.9887
#   ARI: -0.0001

# %%
# KMeans визуализация - два графика: полный и увеличенный
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# График 1: Полные данные
scatter1 = axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, 
                          cmap='viridis', alpha=0.6, 
                          edgecolors='black', linewidths=0.5, s=10)
axes[0].set_xlabel('PC1')
axes[0].set_ylabel('PC2')
axes[0].set_title(f'KMeans все данные (ARI={ari_kmeans:.4f})')
axes[0].grid(True, alpha=0.3)

# График 2: Увеличенная область основного облака
# Определяем границы основного облака (где ~95% данных)
main_area_mask = (X_pca[:, 0] > -10) & (X_pca[:, 0] < 10) & \
                 (X_pca[:, 1] > -10) & (X_pca[:, 1] < 10)

scatter2 = axes[1].scatter(X_pca[main_area_mask, 0], X_pca[main_area_mask, 1], 
                          c=kmeans_labels[main_area_mask], cmap='viridis', 
                          alpha=0.7, edgecolors='black', linewidths=0.5, s=20)
axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title('KMeans: увеличенная область основного облака (-10, 10)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Дополнительная информация о количестве точек в увеличенной области
print(f"Всего точек: {len(kmeans_labels)}")
print(f"Точек в увеличенной области (-10, 10): {main_area_mask.sum()} ({main_area_mask.sum()/len(kmeans_labels):.1%})")
print(f"Кластеров в увеличенной области: {np.unique(kmeans_labels[main_area_mask])}")
# Out:
# Всего точек: 19967
# Точек в увеличенной области (-10, 10): 19927 (99.8%)
# Кластеров в увеличенной области: [0]

# %% [markdown]
# DBSCAN

# %%
# Подбор параметров DBSCAN
best_score = -1
best_params = None
best_labels = None

for eps in [0.5, 1.0, 1.5, 2.0]:
    for min_samples in [5, 10, 15, 20]:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(X_scaled)
        
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise = list(labels).count(-1)
        
        if n_clusters < 2 or n_noise > len(labels) * 0.5:
            continue
            
        non_noise_mask = labels != -1
        if non_noise_mask.sum() > n_clusters:
            score = silhouette_score(X_scaled[non_noise_mask], labels[non_noise_mask])
            if score > best_score:
                best_score = score
                best_params = (eps, min_samples)
                best_labels = labels

if best_labels is not None:
    eps_best, min_samples_best = best_params
    print(f"Лучшие параметры: eps={eps_best}, min_samples={min_samples_best}")
    print(f"Silhouette Score: {best_score:.4f}")
else:
    print("DBSCAN не нашел подходящих параметров")
    dbscan = DBSCAN(eps=1.5, min_samples=10)
    best_labels = dbscan.fit_predict(X_scaled)
    best_params = (1.5, 10)
# Out:
# Лучшие параметры: eps=1.5, min_samples=10
# Silhouette Score: 0.4728

# %%
# Визуализация DBSCAN - два графика рядом
dbscan_labels = best_labels
n_clusters_dbscan = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)
ari_dbscan = adjusted_rand_score(y_true, dbscan_labels)
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# График 1: Все данные (как у вас было)
non_noise_mask = dbscan_labels != -1
noise_mask = dbscan_labels == -1

if noise_mask.sum() > 0:
    axes[0].scatter(X_pca[noise_mask, 0], X_pca[noise_mask, 1], 
                   c='lightgray', alpha=0.3, s=10, label='Шум')
               
axes[0].scatter(X_pca[non_noise_mask, 0], X_pca[non_noise_mask, 1], 
               c=dbscan_labels[non_noise_mask], cmap='viridis', alpha=0.6, 
               edgecolors='black', linewidths=0.5)
axes[0].set_xlabel('PC1')
axes[0].set_ylabel('PC2')
axes[0].set_title(f'DBSCAN все данные (кластеров: {n_clusters_dbscan})')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# График 2: Только основное облако
x_center = np.percentile(X_pca[:, 0], 50)
y_center = np.percentile(X_pca[:, 1], 50)
x_range = 10
y_range = 10

mask_main = (X_pca[:, 0] > x_center - x_range) & (X_pca[:, 0] < x_center + x_range) & \
            (X_pca[:, 1] > y_center - y_range) & (X_pca[:, 1] < y_center + y_range)

mask_main_noise = mask_main & (dbscan_labels == -1)
mask_main_clusters = mask_main & (dbscan_labels != -1)

# Шум в основной области
if mask_main_noise.sum() > 0:
    axes[1].scatter(X_pca[mask_main_noise, 0], X_pca[mask_main_noise, 1], 
                   c='lightgray', alpha=0.3, s=10, label='Шум')

# Кластеры 0 и 1 с фиолетовым и желтым
cluster_colors = {0: 'purple', 1: 'yellow'}

for cluster in [0, 1]:
    mask_cluster = mask_main_clusters & (dbscan_labels == cluster)
    if mask_cluster.sum() > 0:
        axes[1].scatter(X_pca[mask_cluster, 0], X_pca[mask_cluster, 1], 
                       c=cluster_colors[cluster], alpha=0.7,
                       s=20, edgecolors='black', linewidths=0.5,
                       label=f'Кластер {cluster}')

axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title(f'DBSCAN основное облако (ARI={ari_dbscan:.4f})')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Agglomerative Clustering

# %%
# Используем то же количество кластеров что и в KMeans
n_clusters_agglo = optimal_k

# Пробуем разные методы связности
best_agglo_score = -1
best_agglo_linkage = None
best_agglo_labels = None

for linkage in ['ward', 'complete', 'average']:
    agglo = AgglomerativeClustering(n_clusters=n_clusters_agglo, linkage=linkage)
    labels = agglo.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    
    if score > best_agglo_score:
        best_agglo_score = score
        best_agglo_linkage = linkage
        best_agglo_labels = labels

print(f"Лучший метод связности: {best_agglo_linkage}")
print(f"Silhouette Score: {best_agglo_score:.4f}")
# Out:
# Лучший метод связности: ward
# Silhouette Score: 0.9887

# %%
# Результаты Agglomerative
agglo_labels = best_agglo_labels

# Метрики
ari_agglo = adjusted_rand_score(y_true, agglo_labels)

print(f"Agglomerative Clustering (n_clusters={n_clusters_agglo}, linkage={best_agglo_linkage}):")
print(f"  Silhouette Score: {best_agglo_score:.4f}")
print(f"  ARI: {ari_agglo:.4f}")

# Визуализация
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=agglo_labels, cmap='Set2', alpha=0.6, edgecolors='black', linewidths=0.5)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Agglomerative Clustering')
plt.colorbar(label='Кластер')
plt.show()
# Out:
# Agglomerative Clustering (n_clusters=2, linkage=ward):
#   Silhouette Score: 0.9887
#   ARI: -0.0001

# %%
# Agglomerative Clustering визуализация - два графика: полный и увеличенный
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# График 1: Полные данные
scatter1 = axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=agglo_labels, 
                          cmap='Set2', alpha=0.6, 
                          edgecolors='black', linewidths=0.5, s=10)
axes[0].set_xlabel('PC1')
axes[0].set_ylabel('PC2')
axes[0].set_title(f'Agglomerative все данные (ARI={ari_agglo:.4f})')
axes[0].grid(True, alpha=0.3)

# График 2: Увеличенная область основного облака
# Определяем границы основного облака (где ~95% данных)
main_area_mask = (X_pca[:, 0] > -10) & (X_pca[:, 0] < 10) & \
                 (X_pca[:, 1] > -10) & (X_pca[:, 1] < 10)

# Используем фиолетовый и желтый для кластеров, как в DBSCAN для единообразия
cluster_colors = {0: 'purple', 1: 'yellow'}

# Рисуем каждый кластер отдельно с нужным цветом
for cluster in [0, 1]:
    cluster_mask = main_area_mask & (agglo_labels == cluster)
    if cluster_mask.sum() > 0:
        axes[1].scatter(X_pca[cluster_mask, 0], X_pca[cluster_mask, 1], 
                       c=cluster_colors[cluster], alpha=0.7,
                       s=20, edgecolors='black', linewidths=0.5,
                       label=f'Кластер {cluster}')

axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title(f'Agglomerative: увеличенная область (-10, 10)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Дополнительная информация о количестве точек в увеличенной области
print(f"Всего точек: {len(agglo_labels)}")
print(f"Точек в увеличенной области (-10, 10): {main_area_mask.sum()} ({main_area_mask.sum()/len(agglo_labels):.1%})")

# Анализ кластеров в увеличенной области
print("\nАнализ кластеров в увеличенной области (-10, 10):")
for cluster in [0, 1]:
    cluster_mask = main_area_mask & (agglo_labels == cluster)
    if cluster_mask.sum() > 0:
        n_bankrupt = np.sum(y_true[cluster_mask] == 1)
        n_non_bankrupt = np.sum(y_true[cluster_mask] == 0)
        total = n_bankrupt + n_non_bankrupt
        print(f"Кластер {cluster}: {total} объектов")
        print(f"  Банкротов: {n_bankrupt} ({n_bankrupt/total:.1%})")
        print(f"  Не банкротов: {n_non_bankrupt}")
# Out:
# Всего точек: 19967
# Точек в увеличенной области (-10, 10): 19927 (99.8%)
#
# Анализ кластеров в увеличенной области (-10, 10):
# Кластер 0: 19927 объектов
#   Банкротов: 432 (2.2%)
#   Не банкротов: 19495

# %% [markdown]
# Сравнение всех методов

# %%
# Визуализация всех методов вместе
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# 1. Истинные метки
ax = axes[0, 0]
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], c=y_true, cmap='RdYlGn_r', alpha=0.6, edgecolors='black', linewidths=0.3)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title('Истинные метки (0=не банкрот, 1=банкрот)')
plt.colorbar(scatter, ax=ax)

# 2. KMeans
ax = axes[0, 1]
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis', alpha=0.6, edgecolors='black', linewidths=0.3)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title(f'KMeans (Silh={silhouette_kmeans:.3f}, ARI={ari_kmeans:.3f})')
plt.colorbar(scatter, ax=ax)

# 3. DBSCAN
ax = axes[1, 0]
non_noise = dbscan_labels != -1
ax.scatter(X_pca[~non_noise, 0], X_pca[~non_noise, 1], c='lightgray', alpha=0.3, s=10, label='Шум')
scatter = ax.scatter(X_pca[non_noise, 0], X_pca[non_noise, 1], c=dbscan_labels[non_noise], cmap='viridis', alpha=0.6, edgecolors='black', linewidths=0.3)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title(f'DBSCAN (Silh={best_score:.3f}, ARI={ari_dbscan:.3f})')
ax.legend()
plt.colorbar(scatter, ax=ax)

# 4. Agglomerative
ax = axes[1, 1]
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], c=agglo_labels, cmap='Set2', alpha=0.6, edgecolors='black', linewidths=0.3)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title(f'Agglomerative (Silh={best_agglo_score:.3f}, ARI={ari_agglo:.3f})')
plt.colorbar(scatter, ax=ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# Соответствие кластеров и истинных меток

# %%
from sklearn.metrics import confusion_matrix

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

methods = [
    ('KMeans', kmeans_labels, ari_kmeans),
    ('DBSCAN', dbscan_labels, ari_dbscan),
    ('Agglomerative', agglo_labels, ari_agglo)
]

for idx, (name, labels, ari) in enumerate(methods):
    ax = axes[idx]
    
    # Для DBSCAN убираем шум
    if name == 'DBSCAN':
        mask = labels != -1
        cm = confusion_matrix(y_true[mask], labels[mask])
    else:
        cm = confusion_matrix(y_true, labels)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_xlabel('Кластер')
    ax.set_ylabel('Истинная метка')
    ax.set_title(f'{name} (ARI={ari:.3f})')

plt.tight_layout()
plt.show()

print("Объяснение:")
print("- Строки: истинные метки (0=не банкрот, 1=банкрот)")
print("- Столбцы: найденные кластеры")
print("- Если ARI близок к 0: кластеры НЕ соответствуют банкротству")
# Out:
# Объяснение:
# - Строки: истинные метки (0=не банкрот, 1=банкрот)
# - Столбцы: найденные кластеры
# - Если ARI близок к 0: кластеры НЕ соответствуют банкротству

# %% [markdown]
# Выводы
#
# **Основные результаты:**
#
# 1. **Качество кластеризации (Silhouette Score):**
#    - KMeans и Agglomerative показали высокий Silhouette Score (0.9887), что говорит о четком разделении данных на 2 кластера.
#    - DBSCAN показал более низкий результат (0.4728), но выделил 14.3% данных как шумовые точки.
#
# 2. **Соответствие кластеров истинным меткам (ARI):**
#    - Все методы показали ARI близкий к нулю (от -0.0001 до 0.0107).
#    - Это означает, что найденные кластеры практически НЕ соответствуют разделению на банкротов/небанкротов.
#
# 3. **Интерпретация результатов:**
#    - Методы обучения без учителя успешно нашли структуру в данных (2 четких группы компаний).
#    - Однако эта структура отражает не банкротство, а другие паттерны: возможно, размер компании, отрасль, регион или сочетание финансовых показателей.
#    - График распределения банкротств по кластерам показывает, что в каждом кластере процент банкротов близок к общему проценту.
#
# 4. **Вывод:**
#    - Для предсказания банкротства необходимы методы обучения с учителем (которые были использованы в первой части работы).
#    - Кластеризация выявила другие закономерности в данных, не связанные напрямую с банкротством.
#    - PCA объяснила только 28.3% дисперсии, что указывает на высокую размерность и сложность данных.
